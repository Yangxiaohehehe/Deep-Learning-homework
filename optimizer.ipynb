# %% [markdown]
# # Assignment 1
#
# This code baseline is inspired by and modified from [this great tutorial](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html).
#
# This code can achieve an accuracy of approximately 86.50% on CIFAR-10. Please set up the environment and run your experiments starting from this baseline. You are expected to achieve an accuracy higher than this baseline.

# %%
# import some necessary packages
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision.datasets as tv_datasets
import torchvision.transforms as tv_transforms


import matplotlib.pyplot as plt

# %%
# some experimental setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = 128
batch_size = 128
num_workers = 2
print_every = 200

# optim_name = "Adam"
# optim_kwargs = dict(
#     lr=1e-4,
#     weight_decay=1e-6,
# )

optim_name = "SGD"
optim_kwargs = dict(
    lr=0.005,
    momentum=0.9,
    weight_decay=5e-4,
)


# optim_name = "AdamW"
# optim_kwargs = dict(
#     lr=3e-4,
#     weight_decay=1e-2,
# )

# preprocessing pipeline for input images
transformation = dict()
for data_type in ("train", "test"):
    is_train = data_type=="train"
    transformation[data_type] = tv_transforms.Compose(([
        tv_transforms.RandomRotation(degrees=15),
        tv_transforms.RandomHorizontalFlip(),
        tv_transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    ] if is_train else []) +
    [
        tv_transforms.ToTensor(),
        tv_transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ])

# %%
# prepare datasets
dataset, loader = {}, {}
for data_type in ("train", "test"):
    is_train = data_type=="train"
    dataset[data_type] = tv_datasets.CIFAR10(
        root="./data", train=is_train, download=True, transform=transformation[data_type],
    )
    loader[data_type] = torch.utils.data.DataLoader(
        dataset[data_type], batch_size=batch_size, shuffle=is_train, num_workers=num_workers,
    )
# Out:
# 100%|██████████| 170M/170M [00:03<00:00, 43.1MB/s]

# %%
# our network architecture
net = nn.Sequential(
    nn.Conv2d(3, 128, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2), nn.Dropout(0.3),
    nn.Conv2d(128, 256, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2), nn.Dropout(0.3),
    nn.Conv2d(256, 512, 3, padding=1), nn.ReLU(inplace=True),
    nn.Conv2d(512, 512, 3, padding=1), nn.ReLU(inplace=True),
    nn.Conv2d(512, 256, 3, padding=1), nn.ReLU(inplace=True), nn.MaxPool2d(2), nn.Dropout(0.3),
    nn.Flatten(),
    nn.Linear(256 * 4 * 4, 512), nn.ReLU(inplace=True), nn.Dropout(0.5),
    nn.Linear(512, 256), nn.ReLU(inplace=True), nn.Dropout(0.5),
    nn.Linear(256, 128), nn.ReLU(inplace=True), nn.Dropout(0.5),
    nn.Linear(128, 10),
)

# move to device
net.to(device)

# print the number of parameters
print(f"number of parameters: {sum(p.numel() for p in net.parameters() if p.requires_grad) / 1_000_000:.2f}M")
# Out:
# number of parameters: 7.28M

# %% [markdown]
# ## Start Training

# %%
# the network optimizer
optimizer = getattr(optim, optim_name)(net.parameters(), **optim_kwargs)

# loss function
criterion = nn.CrossEntropyLoss()


loss_history = []
iter_history = []
current_iter = 0
val_loss_history = []
val_acc_history = []
val_iter_history = []

# training loop
net.train()
for epoch in range(num_epochs):
    net.train()
    running_loss = 0.0
    for i, (img, target) in enumerate(loader["train"]):
        img, target = img.to(device), target.to(device)


        pred = net(img)
        loss = criterion(pred, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        current_iter += 1
        if i % print_every == print_every - 1:
            avg_loss = running_loss / print_every
            print(f"[epoch={epoch + 1:3d}, iter={i + 1:5d}] loss: {running_loss / print_every:.3f}")
            iter_history.append(current_iter)
            loss_history.append(avg_loss)
            running_loss = 0.0

    net.eval()
    val_loss = 0.0
    correct, total = 0, 0
    with torch.no_grad():
        for img, target in loader["test"]:
            img, target = img.to(device), target.to(device)
            pred = net(img)
            loss = criterion(pred, target)
            val_loss += loss.item()
            total += len(target)
            correct += (torch.argmax(pred, dim=1) == target).sum().item()

    avg_val_loss = val_loss / len(loader["test"])
    accuracy = 100 * correct / total

    print(f"[Epoch {epoch + 1:3d}] Validation loss: {avg_val_loss:.3f}, Accuracy: {accuracy:.2f}%")
    val_iter_history.append(current_iter)
    val_loss_history.append(avg_val_loss)
    val_acc_history.append(accuracy)

print("Finished Training")
# plot
fig, ax1 = plt.subplots(figsize=(12, 6))
plt.title('Training & Validation Metrics')

ax1.set_xlabel('Iteration')
ax1.set_ylabel('Loss', color='tab:red')
ax1.plot(iter_history, loss_history, color='tab:red', linestyle='--', alpha=0.7, label='Training Loss')
ax1.plot(val_iter_history, val_loss_history, color='tab:orange', marker='o', label='Validation Loss')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel('Accuracy (%)', color='tab:blue')
ax2.plot(val_iter_history, val_acc_history, color='tab:blue', marker='s', label='Validation Accuracy')
ax2.tick_params(axis='y', labelcolor='tab:blue')

fig.legend(loc='upper right', bbox_to_anchor=(0.9, 0.9))

fig.tight_layout()
plt.grid(True)
plt.savefig('all_metrics_curve.png')

print("\nMetrics curve has been saved to all_metrics_curve.png")

print("\nTraining loss curve has been saved to training_loss_curve.png")
# Out:
# [epoch=  1, iter=  200] loss: 2.303
# [Epoch   1] Validation loss: 2.303, Accuracy: 10.00%
# [epoch=  2, iter=  200] loss: 2.303
# [Epoch   2] Validation loss: 2.302, Accuracy: 10.00%
# [epoch=  3, iter=  200] loss: 2.303
# [Epoch   3] Validation loss: 2.302, Accuracy: 10.00%
# [epoch=  4, iter=  200] loss: 2.302
# [Epoch   4] Validation loss: 2.298, Accuracy: 15.47%
# [epoch=  5, iter=  200] loss: 2.286
# [Epoch   5] Validation loss: 2.063, Accuracy: 21.20%
# [epoch=  6, iter=  200] loss: 2.036
# [Epoch   6] Validation loss: 2.004, Accuracy: 21.24%
# [epoch=  7, iter=  200] loss: 1.937
# [Epoch   7] Validation loss: 1.848, Accuracy: 24.89%
# [epoch=  8, iter=  200] loss: 1.892
# [Epoch   8] Validation loss: 1.794, Accuracy: 28.48%
# [epoch=  9, iter=  200] loss: 1.833
# [Epoch   9] Validation loss: 1.740, Accuracy: 32.23%
# [epoch= 10, iter=  200] loss: 1.771
# [Epoch  10] Validation loss: 1.641, Accuracy: 36.56%
# [epoch= 11, iter=  200] loss: 1.702
# [Epoch  11] Validation loss: 1.553, Accuracy: 41.04%
# [epoch= 12, iter=  200] loss: 1.665
# [Epoch  12] Validation loss: 1.501, Accuracy: 43.12%
# [epoch= 13, iter=  200] loss: 1.578
# [Epoch  13] Validation loss: 1.406, Accuracy: 47.52%
# [epoch= 14, iter=  200] loss: 1.516
# [Epoch  14] Validation loss: 1.341, Accuracy: 49.01%
# [epoch= 15, iter=  200] loss: 1.459
# [Epoch  15] Validation loss: 1.283, Accuracy: 51.60%
# [epoch= 16, iter=  200] loss: 1.413
# [Epoch  16] Validation loss: 1.205, Accuracy: 54.94%
# [epoch= 17, iter=  200] loss: 1.358
# [Epoch  17] Validation loss: 1.161, Accuracy: 57.17%
# [epoch= 18, iter=  200] loss: 1.315
# [Epoch  18] Validation loss: 1.137, Accuracy: 57.48%
# [epoch= 19, iter=  200] loss: 1.274
# [Epoch  19] Validation loss: 1.075, Accuracy: 61.04%
# [epoch= 20, iter=  200] loss: 1.231
# [Epoch  20] Validation loss: 1.031, Accuracy: 62.29%
# [epoch= 21, iter=  200] loss: 1.183
# [Epoch  21] Validation loss: 0.995, Accuracy: 64.09%
# [epoch= 22, iter=  200] loss: 1.155
# [Epoch  22] Validation loss: 0.970, Accuracy: 63.97%
# [epoch= 23, iter=  200] loss: 1.119
# [Epoch  23] Validation loss: 0.950, Accuracy: 65.78%
# [epoch= 24, iter=  200] loss: 1.086
# [Epoch  24] Validation loss: 0.939, Accuracy: 66.10%
# [epoch= 25, iter=  200] loss: 1.060
# [Epoch  25] Validation loss: 0.892, Accuracy: 67.73%
# [epoch= 26, iter=  200] loss: 1.029
# [Epoch  26] Validation loss: 0.929, Accuracy: 65.82%
# [epoch= 27, iter=  200] loss: 1.007
# [Epoch  27] Validation loss: 0.836, Accuracy: 69.08%
# [epoch= 28, iter=  200] loss: 0.972
# [Epoch  28] Validation loss: 0.812, Accuracy: 70.80%
# [epoch= 29, iter=  200] loss: 0.966
# [Epoch  29] Validation loss: 0.786, Accuracy: 71.55%
# [epoch= 30, iter=  200] loss: 0.937
# [Epoch  30] Validation loss: 0.833, Accuracy: 70.99%
# [epoch= 31, iter=  200] loss: 0.927
# [Epoch  31] Validation loss: 0.799, Accuracy: 71.64%
# [epoch= 32, iter=  200] loss: 0.891
# [Epoch  32] Validation loss: 0.737, Accuracy: 73.35%
# [epoch= 33, iter=  200] loss: 0.871
# [Epoch  33] Validation loss: 0.751, Accuracy: 73.47%
# [epoch= 34, iter=  200] loss: 0.863
# [Epoch  34] Validation loss: 0.770, Accuracy: 73.64%
# [epoch= 35, iter=  200] loss: 0.834
# [Epoch  35] Validation loss: 0.705, Accuracy: 75.23%
# [epoch= 36, iter=  200] loss: 0.824
# [Epoch  36] Validation loss: 0.710, Accuracy: 75.52%
# [epoch= 37, iter=  200] loss: 0.813
# [Epoch  37] Validation loss: 0.697, Accuracy: 75.76%
# [epoch= 38, iter=  200] loss: 0.795
# [Epoch  38] Validation loss: 0.675, Accuracy: 76.36%
# [epoch= 39, iter=  200] loss: 0.784
# [Epoch  39] Validation loss: 0.652, Accuracy: 77.39%
# [epoch= 40, iter=  200] loss: 0.763
# [Epoch  40] Validation loss: 0.645, Accuracy: 77.50%
# [epoch= 41, iter=  200] loss: 0.754
# [Epoch  41] Validation loss: 0.675, Accuracy: 76.82%
# [epoch= 42, iter=  200] loss: 0.731
# [Epoch  42] Validation loss: 0.628, Accuracy: 78.45%
# [epoch= 43, iter=  200] loss: 0.726
# [Epoch  43] Validation loss: 0.728, Accuracy: 76.39%
# [epoch= 44, iter=  200] loss: 0.716
# [Epoch  44] Validation loss: 0.650, Accuracy: 78.27%
# [epoch= 45, iter=  200] loss: 0.711
# [Epoch  45] Validation loss: 0.616, Accuracy: 78.91%
# [epoch= 46, iter=  200] loss: 0.679
# [Epoch  46] Validation loss: 0.585, Accuracy: 79.85%
# [epoch= 47, iter=  200] loss: 0.688
# [Epoch  47] Validation loss: 0.588, Accuracy: 80.27%
# [epoch= 48, iter=  200] loss: 0.669
# [Epoch  48] Validation loss: 0.565, Accuracy: 80.98%
# [epoch= 49, iter=  200] loss: 0.664
# [Epoch  49] Validation loss: 0.612, Accuracy: 79.99%
# [epoch= 50, iter=  200] loss: 0.656
# [Epoch  50] Validation loss: 0.587, Accuracy: 80.06%
# [epoch= 51, iter=  200] loss: 0.648
# [Epoch  51] Validation loss: 0.568, Accuracy: 81.00%
# [epoch= 52, iter=  200] loss: 0.630
# [Epoch  52] Validation loss: 0.593, Accuracy: 80.72%
# [epoch= 53, iter=  200] loss: 0.615
# [Epoch  53] Validation loss: 0.554, Accuracy: 81.80%
# [epoch= 54, iter=  200] loss: 0.606
# [Epoch  54] Validation loss: 0.552, Accuracy: 81.56%
# [epoch= 55, iter=  200] loss: 0.599
# [Epoch  55] Validation loss: 0.583, Accuracy: 81.22%
# [epoch= 56, iter=  200] loss: 0.592
# [Epoch  56] Validation loss: 0.522, Accuracy: 82.61%
# [epoch= 57, iter=  200] loss: 0.575
# [Epoch  57] Validation loss: 0.518, Accuracy: 83.07%
# [epoch= 58, iter=  200] loss: 0.563
# [Epoch  58] Validation loss: 0.520, Accuracy: 83.02%
# [epoch= 59, iter=  200] loss: 0.564
# [Epoch  59] Validation loss: 0.498, Accuracy: 83.73%
# [epoch= 60, iter=  200] loss: 0.560
# [Epoch  60] Validation loss: 0.514, Accuracy: 83.18%
# [epoch= 61, iter=  200] loss: 0.552
# [Epoch  61] Validation loss: 0.512, Accuracy: 83.75%
# [epoch= 62, iter=  200] loss: 0.533
# [Epoch  62] Validation loss: 0.522, Accuracy: 83.30%
# [epoch= 63, iter=  200] loss: 0.532
# [Epoch  63] Validation loss: 0.496, Accuracy: 83.95%
# [epoch= 64, iter=  200] loss: 0.520
# [Epoch  64] Validation loss: 0.483, Accuracy: 84.33%
# [epoch= 65, iter=  200] loss: 0.502
# [Epoch  65] Validation loss: 0.503, Accuracy: 84.32%
# [epoch= 66, iter=  200] loss: 0.507
# [Epoch  66] Validation loss: 0.481, Accuracy: 84.45%
# [epoch= 67, iter=  200] loss: 0.495
# [Epoch  67] Validation loss: 0.483, Accuracy: 84.18%
# [epoch= 68, iter=  200] loss: 0.514
# [Epoch  68] Validation loss: 0.486, Accuracy: 84.45%
# [epoch= 69, iter=  200] loss: 0.483
# [Epoch  69] Validation loss: 0.485, Accuracy: 84.61%
# [epoch= 70, iter=  200] loss: 0.479
# [Epoch  70] Validation loss: 0.488, Accuracy: 84.75%
# [epoch= 71, iter=  200] loss: 0.485
# [Epoch  71] Validation loss: 0.508, Accuracy: 84.08%
# [epoch= 72, iter=  200] loss: 0.474
# [Epoch  72] Validation loss: 0.491, Accuracy: 84.73%
# [epoch= 73, iter=  200] loss: 0.460
# [Epoch  73] Validation loss: 0.474, Accuracy: 84.89%
# [epoch= 74, iter=  200] loss: 0.454
# [Epoch  74] Validation loss: 0.475, Accuracy: 84.88%
# [epoch= 75, iter=  200] loss: 0.457
# [Epoch  75] Validation loss: 0.461, Accuracy: 85.46%
# [epoch= 76, iter=  200] loss: 0.446
# [Epoch  76] Validation loss: 0.487, Accuracy: 84.58%
# [epoch= 77, iter=  200] loss: 0.445
# [Epoch  77] Validation loss: 0.453, Accuracy: 85.82%
# [epoch= 78, iter=  200] loss: 0.436
# [Epoch  78] Validation loss: 0.505, Accuracy: 84.62%
# [epoch= 79, iter=  200] loss: 0.424
# [Epoch  79] Validation loss: 0.501, Accuracy: 84.59%
# [epoch= 80, iter=  200] loss: 0.420
# [Epoch  80] Validation loss: 0.444, Accuracy: 85.80%
# [epoch= 81, iter=  200] loss: 0.418
# [Epoch  81] Validation loss: 0.517, Accuracy: 84.68%
# [epoch= 82, iter=  200] loss: 0.403
# [Epoch  82] Validation loss: 0.446, Accuracy: 85.57%
# [epoch= 83, iter=  200] loss: 0.409
# [Epoch  83] Validation loss: 0.463, Accuracy: 86.22%
# [epoch= 84, iter=  200] loss: 0.404
# [Epoch  84] Validation loss: 0.430, Accuracy: 86.46%
# [epoch= 85, iter=  200] loss: 0.401
# [Epoch  85] Validation loss: 0.505, Accuracy: 84.98%
# [epoch= 86, iter=  200] loss: 0.407
# [Epoch  86] Validation loss: 0.469, Accuracy: 85.71%
# [epoch= 87, iter=  200] loss: 0.392
# [Epoch  87] Validation loss: 0.447, Accuracy: 86.31%
# [epoch= 88, iter=  200] loss: 0.373
# [Epoch  88] Validation loss: 0.464, Accuracy: 85.88%
# [epoch= 89, iter=  200] loss: 0.379
# [Epoch  89] Validation loss: 0.440, Accuracy: 86.13%
# [epoch= 90, iter=  200] loss: 0.360
# [Epoch  90] Validation loss: 0.431, Accuracy: 86.64%
# [epoch= 91, iter=  200] loss: 0.374
# [Epoch  91] Validation loss: 0.453, Accuracy: 86.15%
# [epoch= 92, iter=  200] loss: 0.367
# [Epoch  92] Validation loss: 0.443, Accuracy: 86.17%
# [epoch= 93, iter=  200] loss: 0.361
# [Epoch  93] Validation loss: 0.455, Accuracy: 85.92%
# [epoch= 94, iter=  200] loss: 0.364
# [Epoch  94] Validation loss: 0.531, Accuracy: 84.40%
# [epoch= 95, iter=  200] loss: 0.350
# [Epoch  95] Validation loss: 0.428, Accuracy: 86.79%
# [epoch= 96, iter=  200] loss: 0.358
# [Epoch  96] Validation loss: 0.445, Accuracy: 86.86%
# [epoch= 97, iter=  200] loss: 0.347
# [Epoch  97] Validation loss: 0.442, Accuracy: 86.71%
# [epoch= 98, iter=  200] loss: 0.338
# [Epoch  98] Validation loss: 0.421, Accuracy: 87.14%
# [epoch= 99, iter=  200] loss: 0.345
# [Epoch  99] Validation loss: 0.451, Accuracy: 86.42%
# [epoch=100, iter=  200] loss: 0.336
# [Epoch 100] Validation loss: 0.445, Accuracy: 86.83%
# [epoch=101, iter=  200] loss: 0.335
# [Epoch 101] Validation loss: 0.438, Accuracy: 86.91%
# [epoch=102, iter=  200] loss: 0.328
# [Epoch 102] Validation loss: 0.439, Accuracy: 86.52%
# [epoch=103, iter=  200] loss: 0.312
# [Epoch 103] Validation loss: 0.434, Accuracy: 87.02%
# [epoch=104, iter=  200] loss: 0.319
# [Epoch 104] Validation loss: 0.423, Accuracy: 87.32%
# [epoch=105, iter=  200] loss: 0.311
# [Epoch 105] Validation loss: 0.454, Accuracy: 86.47%
# [epoch=106, iter=  200] loss: 0.307
# [Epoch 106] Validation loss: 0.433, Accuracy: 87.05%
# [epoch=107, iter=  200] loss: 0.303
# [Epoch 107] Validation loss: 0.478, Accuracy: 86.15%
# [epoch=108, iter=  200] loss: 0.306
# [Epoch 108] Validation loss: 0.449, Accuracy: 86.90%
# [epoch=109, iter=  200] loss: 0.304
# [Epoch 109] Validation loss: 0.495, Accuracy: 86.50%
# [epoch=110, iter=  200] loss: 0.303
# [Epoch 110] Validation loss: 0.421, Accuracy: 87.45%
# [epoch=111, iter=  200] loss: 0.290
# [Epoch 111] Validation loss: 0.491, Accuracy: 85.99%
# [epoch=112, iter=  200] loss: 0.294
# [Epoch 112] Validation loss: 0.445, Accuracy: 86.75%
# [epoch=113, iter=  200] loss: 0.292
# [Epoch 113] Validation loss: 0.448, Accuracy: 86.92%
# [epoch=114, iter=  200] loss: 0.288
# [Epoch 114] Validation loss: 0.449, Accuracy: 86.96%
# [epoch=115, iter=  200] loss: 0.285
# [Epoch 115] Validation loss: 0.442, Accuracy: 86.89%
# [epoch=116, iter=  200] loss: 0.290
# [Epoch 116] Validation loss: 0.428, Accuracy: 87.69%
# [epoch=117, iter=  200] loss: 0.274
# [Epoch 117] Validation loss: 0.462, Accuracy: 87.08%
# [epoch=118, iter=  200] loss: 0.267
# [Epoch 118] Validation loss: 0.445, Accuracy: 87.26%
# [epoch=119, iter=  200] loss: 0.273
# [Epoch 119] Validation loss: 0.419, Accuracy: 87.60%
# [epoch=120, iter=  200] loss: 0.269
# [Epoch 120] Validation loss: 0.432, Accuracy: 87.62%
# [epoch=121, iter=  200] loss: 0.259
# [Epoch 121] Validation loss: 0.475, Accuracy: 86.54%
# [epoch=122, iter=  200] loss: 0.267
# [Epoch 122] Validation loss: 0.476, Accuracy: 86.29%
# [epoch=123, iter=  200] loss: 0.270
# [Epoch 123] Validation loss: 0.434, Accuracy: 87.33%
# [epoch=124, iter=  200] loss: 0.253
# [Epoch 124] Validation loss: 0.447, Accuracy: 87.22%
# [epoch=125, iter=  200] loss: 0.256
# [Epoch 125] Validation loss: 0.464, Accuracy: 87.31%
# [epoch=126, iter=  200] loss: 0.252
# [Epoch 126] Validation loss: 0.441, Accuracy: 87.49%
# [epoch=127, iter=  200] loss: 0.246
# [Epoch 127] Validation loss: 0.464, Accuracy: 86.63%
# [epoch=128, iter=  200] loss: 0.244
# [Epoch 128] Validation loss: 0.450, Accuracy: 87.17%
# Finished Training
#
# Metrics curve has been saved to all_metrics_curve.png
#
# Training loss curve has been saved to training_loss_curve.png

# %% [markdown]
# ## Evaluating its accuracy

# %%
net.eval()
correct, total = 0, 0
with torch.no_grad():
    for img, target in loader["test"]:
        img, target = img.to(device), target.to(device)

        # make prediction
        pred = net(img)

        # accumulate
        total += len(target)
        correct += (torch.argmax(pred, dim=1) == target).sum().item()

print(f"Accuracy of the network on the {total} test images: {100 * correct / total:.2f}%")
# Out:
# Accuracy of the network on the 10000 test images: 87.17%
