# %% [markdown]
# # Assignment 1
#
# This code baseline is inspired by and modified from [this great tutorial](https://pytorch.org/tutorials/beginner/blitz/cifar10_tutorial.html).
#
# This code can achieve an accuracy of approximately 86.50% on CIFAR-10. Please set up the environment and run your experiments starting from this baseline. You are expected to achieve an accuracy higher than this baseline.

# %%
# import some necessary packages
import torch
import torch.nn as nn
import torch.optim as optim

import torchvision.datasets as tv_datasets
import torchvision.transforms as tv_transforms


import matplotlib.pyplot as plt

# %%
# 残差结构
class Resblock(nn.Module):
  def __init__(self,in_channel,out_channel,downsample=False):
    super().__init__()
    self.in_channel = in_channel
    self.out_channel = out_channel
    self.downsample = downsample
    strides = 2 if self.downsample else 1
    if self.downsample or in_channel!=out_channel:
      self.conv3 = nn.Conv2d(in_channel,out_channel,kernel_size=1,stride=strides,padding=0,bias=False)

    self.conv1 = nn.Conv2d(in_channel,out_channel,kernel_size=3,stride =strides,padding =1,bias=False)
    self.bn1  = nn.BatchNorm2d(out_channel)
    self.relu1 = nn.ReLU(inplace = True)
    self.bn2  = nn.BatchNorm2d(out_channel)
    self.conv2 = nn.Conv2d(out_channel,out_channel,kernel_size=3,stride=1,padding=1,bias=False)
    self.relu2 = nn.ReLU(inplace = True)

  def forward(self,x):
    identity = x
    Y = self.relu1(self.bn1(self.conv1(x)))
    Y = self.bn2(self.conv2(Y))
    if self.downsample or self.in_channel!=self.out_channel:
      identity = self.conv3(identity)
    Y=Y+identity
    return self.relu2(Y)

# %%
# attention
class SEBlock(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16):
        super(SEBlock, self).__init__()
        self.squeeze = nn.AdaptiveAvgPool2d(1)

        self.excitation = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction_ratio, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction_ratio, in_channels, bias=False),
            nn.Sigmoid()
        )

    def forward(self, x):
        b, c, _, _ = x.size()
        # y: [B, C, 1, 1] -> [B, C]
        y = self.squeeze(x).view(b, c)
        # y: [B, C] -> [B, C] (通道权重) -> [B, C, 1, 1]
        y = self.excitation(y).view(b, c, 1, 1)
        return x * y.expand_as(x)

class ChannelAttentionModule(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16):
        super(ChannelAttentionModule, self).__init__()
        self.shared_mlp = nn.Sequential(
            nn.Linear(in_channels, in_channels // reduction_ratio, bias=False),
            nn.ReLU(inplace=True),
            nn.Linear(in_channels // reduction_ratio, in_channels, bias=False)
        )
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        b, c, _, _ = x.size()

        avg_out = self.shared_mlp(torch.mean(x, dim=[2, 3])).view(b, c, 1, 1)
        max_out = self.shared_mlp(torch.max(x, dim=3)[0].max(dim=2)[0]).view(b, c, 1, 1)
        channel_weights = self.sigmoid(avg_out + max_out)

        return x * channel_weights
class SpatialAttentionModule(nn.Module):
    def __init__(self, kernel_size=7):
        super(SpatialAttentionModule, self).__init__()
        padding = (kernel_size - 1) // 2
        self.conv = nn.Conv2d(in_channels=2, out_channels=1, kernel_size=kernel_size, padding=padding, bias=False)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        original_input = x
        avg_out = torch.mean(x, dim=1, keepdim=True)
        max_out, _ = torch.max(x, dim=1, keepdim=True)
        concatenated = torch.cat([avg_out, max_out], dim=1)
        spatial_weights = self.conv(concatenated)
        spatial_weights = self.sigmoid(spatial_weights)
        return original_input * spatial_weights
class CBAM(nn.Module):
    def __init__(self, in_channels, reduction_ratio=16, kernel_size=7):
        super(CBAM, self).__init__()
        self.channel_attention = ChannelAttentionModule(in_channels, reduction_ratio)
        self.spatial_attention = SpatialAttentionModule(kernel_size)

    def forward(self, x):
        x = self.channel_attention(x)
        x = self.spatial_attention(x)
        return x

# %%
# some experimental setup
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")

num_epochs = 128
batch_size = 128
num_workers = 2
print_every = 200

optim_name = "Adam"
optim_kwargs = dict(
    lr=1e-4,
    weight_decay=1e-6,
)

# preprocessing pipeline for input images
transformation = dict()
for data_type in ("train", "test"):
    is_train = data_type=="train"
    transformation[data_type] = tv_transforms.Compose(([
        tv_transforms.RandomRotation(degrees=15),
        tv_transforms.RandomHorizontalFlip(),
        tv_transforms.RandomAffine(degrees=0, translate=(0.1, 0.1)),
    ] if is_train else []) +
    [
        tv_transforms.ToTensor(),
        tv_transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5]),
    ])

# %%
# prepare datasets
dataset, loader = {}, {}
for data_type in ("train", "test"):
    is_train = data_type=="train"
    dataset[data_type] = tv_datasets.CIFAR10(
        root="./data", train=is_train, download=True, transform=transformation[data_type],
    )
    loader[data_type] = torch.utils.data.DataLoader(
        dataset[data_type], batch_size=batch_size, shuffle=is_train, num_workers=num_workers,
    )
# Out:
# 100%|██████████| 170M/170M [00:05<00:00, 29.3MB/s]

# %%
class CIFAR_Net_Resblock_CBAM(nn.Module):
    def __init__(self, num_classes=10): # Added num_classes for flexibility
        super().__init__()

        self.stem = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(inplace=True)
        )

        self.layer1 = Resblock(in_channel=64,  out_channel=128, downsample=True)
        self.cbam1 = CBAM(in_channels=128)

        self.layer2 = Resblock(in_channel=128,  out_channel=128, downsample=False)
        self.cbam2 = CBAM(in_channels=128)

        self.layer3 = Resblock(in_channel=128, out_channel=256, downsample=True)
        self.cbam3 = CBAM(in_channels=256)

        self.layer4 = Resblock(in_channel=256, out_channel=256, downsample=False)
        self.cbam4 = CBAM(in_channels=256)

        self.layer5 = Resblock(in_channel=256, out_channel=512, downsample=True)
        self.cbam5 = CBAM(in_channels=512)

        self.layer6 = Resblock(in_channel=512, out_channel=512)
        self.cbam6 = CBAM(in_channels=512)

        self.final_pool = nn.AdaptiveAvgPool2d((1, 1))

        self.classifier = nn.Sequential(
            nn.Flatten(),
            nn.Linear(512, 256), nn.ReLU(inplace=True), nn.Dropout(0.4),
            nn.Linear(256, 128), nn.ReLU(inplace=True), nn.Dropout(0.4),
            nn.Linear(128, num_classes) # Use num_classes
        )

    def forward(self, x):
        x = self.stem(x)

        x = self.layer1(x)
        x = self.cbam1(x)

        x = self.layer2(x)
        x = self.cbam2(x)

        x = self.layer3(x)
        x = self.cbam3(x)

        x = self.layer4(x)
        x = self.cbam4(x)

        x = self.layer5(x)
        x = self.cbam5(x)

        x = self.layer6(x)
        x = self.cbam6(x)

        x = self.final_pool(x)
        x = self.classifier(x)

        return x

net = CIFAR_Net_Resblock_CBAM(num_classes=10)

# %%
# our network architecture
# move to device
net.to(device)

# print the number of parameters
print(f"number of parameters: {sum(p.numel() for p in net.parameters() if p.requires_grad) / 1_000_000:.2f}M")
# Out:
# number of parameters: 11.27M

# %% [markdown]
# ## Start Training

# %%
# the network optimizer
optimizer = getattr(optim, optim_name)(net.parameters(), **optim_kwargs)

# loss function
criterion = nn.CrossEntropyLoss()

# add
loss_history = []
iter_history = []
current_iter = 0
val_loss_history = []
val_acc_history = []
val_iter_history = []

# training loop
net.train()
for epoch in range(num_epochs):
    net.train()
    running_loss = 0.0
    for i, (img, target) in enumerate(loader["train"]):
        img, target = img.to(device), target.to(device)


        pred = net(img)
        loss = criterion(pred, target)

        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        running_loss += loss.item()
        current_iter += 1
        if i % print_every == print_every - 1:
            avg_loss = running_loss / print_every
            print(f"[epoch={epoch + 1:3d}, iter={i + 1:5d}] loss: {running_loss / print_every:.3f}")
            iter_history.append(current_iter)
            loss_history.append(avg_loss)
            running_loss = 0.0

    net.eval()
    val_loss = 0.0
    correct, total = 0, 0
    with torch.no_grad():
        for img, target in loader["test"]:
            img, target = img.to(device), target.to(device)
            pred = net(img)
            loss = criterion(pred, target)
            val_loss += loss.item()
            total += len(target)
            correct += (torch.argmax(pred, dim=1) == target).sum().item()

    avg_val_loss = val_loss / len(loader["test"])
    accuracy = 100 * correct / total

    print(f"[Epoch {epoch + 1:3d}] Validation loss: {avg_val_loss:.3f}, Accuracy: {accuracy:.2f}%")
    val_iter_history.append(current_iter)
    val_loss_history.append(avg_val_loss)
    val_acc_history.append(accuracy)

print("Finished Training")
# plot
fig, ax1 = plt.subplots(figsize=(12, 6))
plt.title('Training & Validation Metrics')
ax1.set_xlabel('Iteration')
ax1.set_ylabel('Loss', color='tab:red')
ax1.plot(iter_history, loss_history, color='tab:red', linestyle='--', alpha=0.7, label='Training Loss')
ax1.plot(val_iter_history, val_loss_history, color='tab:orange', marker='o', label='Validation Loss')
ax1.tick_params(axis='y', labelcolor='tab:red')

ax2 = ax1.twinx()
ax2.set_ylabel('Accuracy (%)', color='tab:blue')
ax2.plot(val_iter_history, val_acc_history, color='tab:blue', marker='s', label='Validation Accuracy')
ax2.tick_params(axis='y', labelcolor='tab:blue')

fig.legend(loc='upper right', bbox_to_anchor=(0.9, 0.9))

fig.tight_layout()
plt.grid(True)
plt.savefig('all_metrics_curve.png')

print("\nMetrics curve has been saved to all_metrics_curve.png")

print("\nTraining loss curve has been saved to training_loss_curve.png")
# Out:
# [epoch=  1, iter=  200] loss: 1.951
# [Epoch   1] Validation loss: 1.591, Accuracy: 44.64%
# [epoch=  2, iter=  200] loss: 1.336
# [Epoch   2] Validation loss: 1.027, Accuracy: 64.07%
# [epoch=  3, iter=  200] loss: 1.096
# [Epoch   3] Validation loss: 0.931, Accuracy: 67.60%
# [epoch=  4, iter=  200] loss: 0.941
# [Epoch   4] Validation loss: 0.823, Accuracy: 71.46%
# [epoch=  5, iter=  200] loss: 0.834
# [Epoch   5] Validation loss: 0.801, Accuracy: 73.06%
# [epoch=  6, iter=  200] loss: 0.744
# [Epoch   6] Validation loss: 0.710, Accuracy: 76.33%
# [epoch=  7, iter=  200] loss: 0.687
# [Epoch   7] Validation loss: 0.625, Accuracy: 78.93%
# [epoch=  8, iter=  200] loss: 0.635
# [Epoch   8] Validation loss: 0.600, Accuracy: 80.38%
# [epoch=  9, iter=  200] loss: 0.591
# [Epoch   9] Validation loss: 0.533, Accuracy: 82.13%
# [epoch= 10, iter=  200] loss: 0.549
# [Epoch  10] Validation loss: 0.539, Accuracy: 82.04%
# [epoch= 11, iter=  200] loss: 0.522
# [Epoch  11] Validation loss: 0.490, Accuracy: 83.70%
# [epoch= 12, iter=  200] loss: 0.493
# [Epoch  12] Validation loss: 0.515, Accuracy: 82.75%
# [epoch= 13, iter=  200] loss: 0.470
# [Epoch  13] Validation loss: 0.489, Accuracy: 84.27%
# [epoch= 14, iter=  200] loss: 0.440
# [Epoch  14] Validation loss: 0.459, Accuracy: 84.52%
# [epoch= 15, iter=  200] loss: 0.430
# [Epoch  15] Validation loss: 0.497, Accuracy: 83.50%
# [epoch= 16, iter=  200] loss: 0.410
# [Epoch  16] Validation loss: 0.475, Accuracy: 84.19%
# [epoch= 17, iter=  200] loss: 0.393
# [Epoch  17] Validation loss: 0.450, Accuracy: 85.45%
# [epoch= 18, iter=  200] loss: 0.377
# [Epoch  18] Validation loss: 0.421, Accuracy: 86.55%
# [epoch= 19, iter=  200] loss: 0.362
# [Epoch  19] Validation loss: 0.452, Accuracy: 85.40%
# [epoch= 20, iter=  200] loss: 0.351
# [Epoch  20] Validation loss: 0.410, Accuracy: 86.77%
# [epoch= 21, iter=  200] loss: 0.328
# [Epoch  21] Validation loss: 0.419, Accuracy: 86.88%
# [epoch= 22, iter=  200] loss: 0.324
# [Epoch  22] Validation loss: 0.418, Accuracy: 86.66%
# [epoch= 23, iter=  200] loss: 0.306
# [Epoch  23] Validation loss: 0.412, Accuracy: 87.00%
# [epoch= 24, iter=  200] loss: 0.298
# [Epoch  24] Validation loss: 0.409, Accuracy: 86.97%
# [epoch= 25, iter=  200] loss: 0.286
# [Epoch  25] Validation loss: 0.422, Accuracy: 86.65%
# [epoch= 26, iter=  200] loss: 0.274
# [Epoch  26] Validation loss: 0.396, Accuracy: 87.91%
# [epoch= 27, iter=  200] loss: 0.261
# [Epoch  27] Validation loss: 0.403, Accuracy: 87.40%
# [epoch= 28, iter=  200] loss: 0.255
# [Epoch  28] Validation loss: 0.431, Accuracy: 86.25%
# [epoch= 29, iter=  200] loss: 0.256
# [Epoch  29] Validation loss: 0.392, Accuracy: 88.36%
# [epoch= 30, iter=  200] loss: 0.236
# [Epoch  30] Validation loss: 0.397, Accuracy: 87.76%
# [epoch= 31, iter=  200] loss: 0.227
# [Epoch  31] Validation loss: 0.426, Accuracy: 87.18%
# [epoch= 32, iter=  200] loss: 0.224
# [Epoch  32] Validation loss: 0.419, Accuracy: 87.81%
# [epoch= 33, iter=  200] loss: 0.216
# [Epoch  33] Validation loss: 0.420, Accuracy: 87.81%
# [epoch= 34, iter=  200] loss: 0.216
# [Epoch  34] Validation loss: 0.388, Accuracy: 88.28%
# [epoch= 35, iter=  200] loss: 0.209
# [Epoch  35] Validation loss: 0.404, Accuracy: 87.78%
# [epoch= 36, iter=  200] loss: 0.203
# [Epoch  36] Validation loss: 0.375, Accuracy: 88.56%
# [epoch= 37, iter=  200] loss: 0.194
# [Epoch  37] Validation loss: 0.388, Accuracy: 88.61%
# [epoch= 38, iter=  200] loss: 0.189
# [Epoch  38] Validation loss: 0.412, Accuracy: 88.36%
# [epoch= 39, iter=  200] loss: 0.183
# [Epoch  39] Validation loss: 0.392, Accuracy: 88.67%
# [epoch= 40, iter=  200] loss: 0.174
# [Epoch  40] Validation loss: 0.398, Accuracy: 88.45%
# [epoch= 41, iter=  200] loss: 0.175
# [Epoch  41] Validation loss: 0.412, Accuracy: 88.15%
# [epoch= 42, iter=  200] loss: 0.168
# [Epoch  42] Validation loss: 0.391, Accuracy: 88.89%
# [epoch= 43, iter=  200] loss: 0.156
# [Epoch  43] Validation loss: 0.446, Accuracy: 88.01%
# [epoch= 44, iter=  200] loss: 0.155
# [Epoch  44] Validation loss: 0.408, Accuracy: 88.36%
# [epoch= 45, iter=  200] loss: 0.161
# [Epoch  45] Validation loss: 0.431, Accuracy: 88.44%
# [epoch= 46, iter=  200] loss: 0.151
# [Epoch  46] Validation loss: 0.444, Accuracy: 88.15%
# [epoch= 47, iter=  200] loss: 0.143
# [Epoch  47] Validation loss: 0.422, Accuracy: 88.48%
# [epoch= 48, iter=  200] loss: 0.145
# [Epoch  48] Validation loss: 0.395, Accuracy: 89.18%
# [epoch= 49, iter=  200] loss: 0.136
# [Epoch  49] Validation loss: 0.433, Accuracy: 88.54%
# [epoch= 50, iter=  200] loss: 0.130
# [Epoch  50] Validation loss: 0.442, Accuracy: 88.42%
# [epoch= 51, iter=  200] loss: 0.135
# [Epoch  51] Validation loss: 0.454, Accuracy: 87.95%
# [epoch= 52, iter=  200] loss: 0.136
# [Epoch  52] Validation loss: 0.439, Accuracy: 88.19%
# [epoch= 53, iter=  200] loss: 0.123
# [Epoch  53] Validation loss: 0.406, Accuracy: 89.31%
# [epoch= 54, iter=  200] loss: 0.126
# [Epoch  54] Validation loss: 0.419, Accuracy: 88.66%
# [epoch= 55, iter=  200] loss: 0.124
# [Epoch  55] Validation loss: 0.429, Accuracy: 89.29%
# [epoch= 56, iter=  200] loss: 0.118
# [Epoch  56] Validation loss: 0.430, Accuracy: 88.75%
# [epoch= 57, iter=  200] loss: 0.121
# [Epoch  57] Validation loss: 0.480, Accuracy: 88.40%
# [epoch= 58, iter=  200] loss: 0.118
# [Epoch  58] Validation loss: 0.462, Accuracy: 88.30%
# [epoch= 59, iter=  200] loss: 0.109
# [Epoch  59] Validation loss: 0.463, Accuracy: 88.59%
# [epoch= 60, iter=  200] loss: 0.110
# [Epoch  60] Validation loss: 0.454, Accuracy: 88.93%
# [epoch= 61, iter=  200] loss: 0.105
# [Epoch  61] Validation loss: 0.433, Accuracy: 89.09%
# [epoch= 62, iter=  200] loss: 0.103
# [Epoch  62] Validation loss: 0.433, Accuracy: 88.92%
# [epoch= 63, iter=  200] loss: 0.105
# [Epoch  63] Validation loss: 0.446, Accuracy: 89.10%
# [epoch= 64, iter=  200] loss: 0.103
# [Epoch  64] Validation loss: 0.477, Accuracy: 88.75%
# [epoch= 65, iter=  200] loss: 0.096
# [Epoch  65] Validation loss: 0.445, Accuracy: 88.50%
# [epoch= 66, iter=  200] loss: 0.097
# [Epoch  66] Validation loss: 0.441, Accuracy: 88.75%
# [epoch= 67, iter=  200] loss: 0.097
# [Epoch  67] Validation loss: 0.412, Accuracy: 89.51%
# [epoch= 68, iter=  200] loss: 0.092
# [Epoch  68] Validation loss: 0.434, Accuracy: 89.17%
# [epoch= 69, iter=  200] loss: 0.085
# [Epoch  69] Validation loss: 0.442, Accuracy: 88.90%
# [epoch= 70, iter=  200] loss: 0.096
# [Epoch  70] Validation loss: 0.465, Accuracy: 88.59%
# [epoch= 71, iter=  200] loss: 0.088
# [Epoch  71] Validation loss: 0.448, Accuracy: 89.20%
# [epoch= 72, iter=  200] loss: 0.083
# [Epoch  72] Validation loss: 0.438, Accuracy: 88.79%
# [epoch= 73, iter=  200] loss: 0.087
# [Epoch  73] Validation loss: 0.462, Accuracy: 89.31%
# [epoch= 74, iter=  200] loss: 0.085
# [Epoch  74] Validation loss: 0.469, Accuracy: 88.31%
# [epoch= 75, iter=  200] loss: 0.079
# [Epoch  75] Validation loss: 0.444, Accuracy: 89.11%
# [epoch= 76, iter=  200] loss: 0.075
# [Epoch  76] Validation loss: 0.484, Accuracy: 88.54%
# [epoch= 77, iter=  200] loss: 0.077
# [Epoch  77] Validation loss: 0.458, Accuracy: 89.33%
# [epoch= 78, iter=  200] loss: 0.071
# [Epoch  78] Validation loss: 0.449, Accuracy: 89.21%
# [epoch= 79, iter=  200] loss: 0.081
# [Epoch  79] Validation loss: 0.478, Accuracy: 89.22%
# [epoch= 80, iter=  200] loss: 0.075
# [Epoch  80] Validation loss: 0.508, Accuracy: 88.59%
# [epoch= 81, iter=  200] loss: 0.074
# [Epoch  81] Validation loss: 0.469, Accuracy: 88.97%
# [epoch= 82, iter=  200] loss: 0.077
# [Epoch  82] Validation loss: 0.446, Accuracy: 89.37%
# [epoch= 83, iter=  200] loss: 0.075
# [Epoch  83] Validation loss: 0.462, Accuracy: 89.30%
# [epoch= 84, iter=  200] loss: 0.071
# [Epoch  84] Validation loss: 0.455, Accuracy: 89.87%
# [epoch= 85, iter=  200] loss: 0.074
# [Epoch  85] Validation loss: 0.486, Accuracy: 88.75%
# [epoch= 86, iter=  200] loss: 0.072
# [Epoch  86] Validation loss: 0.467, Accuracy: 89.46%
# [epoch= 87, iter=  200] loss: 0.069
# [Epoch  87] Validation loss: 0.443, Accuracy: 89.60%
# [epoch= 88, iter=  200] loss: 0.060
# [Epoch  88] Validation loss: 0.472, Accuracy: 89.23%
# [epoch= 89, iter=  200] loss: 0.067
# [Epoch  89] Validation loss: 0.474, Accuracy: 89.22%
# [epoch= 90, iter=  200] loss: 0.063
# [Epoch  90] Validation loss: 0.465, Accuracy: 89.33%
# [epoch= 91, iter=  200] loss: 0.069
# [Epoch  91] Validation loss: 0.477, Accuracy: 89.33%
# [epoch= 92, iter=  200] loss: 0.062
# [Epoch  92] Validation loss: 0.529, Accuracy: 88.54%
# [epoch= 93, iter=  200] loss: 0.062
# [Epoch  93] Validation loss: 0.506, Accuracy: 89.01%
# [epoch= 94, iter=  200] loss: 0.069
# [Epoch  94] Validation loss: 0.460, Accuracy: 89.37%
# [epoch= 95, iter=  200] loss: 0.068
# [Epoch  95] Validation loss: 0.462, Accuracy: 89.37%
# [epoch= 96, iter=  200] loss: 0.061
# [Epoch  96] Validation loss: 0.456, Accuracy: 89.87%
# [epoch= 97, iter=  200] loss: 0.063
# [Epoch  97] Validation loss: 0.467, Accuracy: 89.40%
# [epoch= 98, iter=  200] loss: 0.055
# [Epoch  98] Validation loss: 0.506, Accuracy: 89.29%
# [epoch= 99, iter=  200] loss: 0.065
# [Epoch  99] Validation loss: 0.474, Accuracy: 89.49%
# [epoch=100, iter=  200] loss: 0.061
# [Epoch 100] Validation loss: 0.490, Accuracy: 89.33%
# [epoch=101, iter=  200] loss: 0.056
# [Epoch 101] Validation loss: 0.486, Accuracy: 89.16%
# [epoch=102, iter=  200] loss: 0.056
# [Epoch 102] Validation loss: 0.495, Accuracy: 89.29%
# [epoch=103, iter=  200] loss: 0.058
# [Epoch 103] Validation loss: 0.482, Accuracy: 90.00%
# [epoch=104, iter=  200] loss: 0.056
# [Epoch 104] Validation loss: 0.488, Accuracy: 89.54%
# [epoch=105, iter=  200] loss: 0.054
# [Epoch 105] Validation loss: 0.499, Accuracy: 89.35%
# [epoch=106, iter=  200] loss: 0.059
# [Epoch 106] Validation loss: 0.466, Accuracy: 89.41%
# [epoch=107, iter=  200] loss: 0.056
# [Epoch 107] Validation loss: 0.464, Accuracy: 89.31%
# [epoch=108, iter=  200] loss: 0.054
# [Epoch 108] Validation loss: 0.527, Accuracy: 88.81%
# [epoch=109, iter=  200] loss: 0.054
# [Epoch 109] Validation loss: 0.508, Accuracy: 89.01%
# [epoch=110, iter=  200] loss: 0.055
# [Epoch 110] Validation loss: 0.509, Accuracy: 89.51%
# [epoch=111, iter=  200] loss: 0.059
# [Epoch 111] Validation loss: 0.484, Accuracy: 89.30%
# [epoch=112, iter=  200] loss: 0.045
# [Epoch 112] Validation loss: 0.481, Accuracy: 89.70%
# [epoch=113, iter=  200] loss: 0.052
# [Epoch 113] Validation loss: 0.472, Accuracy: 90.03%
# [epoch=114, iter=  200] loss: 0.051
# [Epoch 114] Validation loss: 0.501, Accuracy: 89.61%
# [epoch=115, iter=  200] loss: 0.050
# [Epoch 115] Validation loss: 0.504, Accuracy: 89.24%
# [epoch=116, iter=  200] loss: 0.048
# [Epoch 116] Validation loss: 0.485, Accuracy: 89.47%
# [epoch=117, iter=  200] loss: 0.047
# [Epoch 117] Validation loss: 0.518, Accuracy: 88.73%
# [epoch=118, iter=  200] loss: 0.047
# [Epoch 118] Validation loss: 0.468, Accuracy: 89.80%
# [epoch=119, iter=  200] loss: 0.046
# [Epoch 119] Validation loss: 0.484, Accuracy: 89.64%
# [epoch=120, iter=  200] loss: 0.049
# [Epoch 120] Validation loss: 0.483, Accuracy: 89.71%
# [epoch=121, iter=  200] loss: 0.042
# [Epoch 121] Validation loss: 0.520, Accuracy: 89.35%
# [epoch=122, iter=  200] loss: 0.048
# [Epoch 122] Validation loss: 0.496, Accuracy: 89.60%
# [epoch=123, iter=  200] loss: 0.044
# [Epoch 123] Validation loss: 0.526, Accuracy: 89.99%
# [epoch=124, iter=  200] loss: 0.046
# [Epoch 124] Validation loss: 0.502, Accuracy: 89.75%
# [epoch=125, iter=  200] loss: 0.040
# [Epoch 125] Validation loss: 0.518, Accuracy: 89.08%
# [epoch=126, iter=  200] loss: 0.046
# [Epoch 126] Validation loss: 0.486, Accuracy: 89.88%
# [epoch=127, iter=  200] loss: 0.045
# [Epoch 127] Validation loss: 0.509, Accuracy: 89.28%
# [epoch=128, iter=  200] loss: 0.047
# [Epoch 128] Validation loss: 0.510, Accuracy: 89.68%
# Finished Training
#
# Metrics curve has been saved to all_metrics_curve.png
#
# Training loss curve has been saved to training_loss_curve.png

# %% [markdown]
# ## Evaluating its accuracy

# %%
net.eval()
correct, total = 0, 0
with torch.no_grad():
    for img, target in loader["test"]:
        img, target = img.to(device), target.to(device)

        # make prediction
        pred = net(img)

        # accumulate
        total += len(target)
        correct += (torch.argmax(pred, dim=1) == target).sum().item()

print(f"Accuracy of the network on the {total} test images: {100 * correct / total:.2f}%")
# Out:
# Accuracy of the network on the 10000 test images: 89.68%
